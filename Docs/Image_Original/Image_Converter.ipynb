# %%
# !ls
# Out:
# Image_Converter.ipynb  img_ISIC_2017.png  img_lungs.png
# img_brain_mri.png      img_kvasir.png	  img_skin_leison.png

# %%
import cv2
import matplotlib.pyplot as plt
im_1 = cv2.imread('img_ISIC_2017.png')
plt.imshow(im_1)
cv2.imwrite('img_ISIC_2017.png',im_1[:,:,::-1])
# Out:
# True

# %%
im_2 = cv2.imread('img_lungs.png')
plt.imshow(im_2)
cv2.imwrite('img_lungs.png',im_2[:,:,-1])
# Out:
# True

# %%
im_3 = cv2.imread('img_brain_mri.png')
plt.imshow(im_3)
cv2.imwrite('img_brain_mri.png',im_3[:,:,-1])
# Out:
# True

# %%
im_4 = cv2.imread('img_kvasir.png')
plt.imshow(im_4)
cv2.imwrite('img_kvasir.png',im_4[:,:,-1])
# Out:
# True

# %%
im_5 = cv2.imread('img_skin_leison.png')
plt.imshow(im_5)
cv2.imwrite('img_skin_leison.png',im_5[:,:,-1])
# Out:
# True
