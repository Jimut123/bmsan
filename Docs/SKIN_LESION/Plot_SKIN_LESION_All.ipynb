# %%
! ls
# Out:
# history_attn_1_bothsides_skinleison.json  Plot_SKIN_LESION_All.ipynb
# history_attnR2Unet_skinLesion.json	  SKIN_LESION_accuracy_coef.eps
# history_attnUNET_skinlesion.json	  SKIN_LESION_dice_coef.eps
# history_multi_res_unet_skinlesion.json	  SKIN_LESION_jacard.eps
# history_orunet_skin_lesion.json		  SKIN_LESION_loss.eps
# history_r2unet_skinlesion.json		  SKIN_LESION_precision.eps
# history_UNet_skinleison.json		  SKIN_LESION_recall.eps

# %%
import json
import matplotlib.pyplot as plt
with open('history_attnR2Unet_skinLesion.json', 'r') as f:
    attnR2Unet = json.load(f)
print (len(attnR2Unet))
# Out:
# 6

# %%
import json
import matplotlib.pyplot as plt
with open('history_r2unet_skinlesion.json', 'r') as f:
    r2unet = json.load(f)
print (len(r2unet))
# Out:
# 6

# %%
import json
import matplotlib.pyplot as plt
with open('history_attnUNET_skinlesion.json', 'r') as f:
    attn_unet = json.load(f)
print (len(attn_unet))
# Out:
# 6

# %%
import json
import matplotlib.pyplot as plt
with open('history_multi_res_unet_skinlesion.json', 'r') as f:
    multi_res_unet = json.load(f)
print (len(multi_res_unet))
# Out:
# 6

# %%
import json
import matplotlib.pyplot as plt
with open('history_UNet_skinleison.json', 'r') as f:
    UNet = json.load(f)
print (len(UNet))
# Out:
# 6

# %%
import json
import matplotlib.pyplot as plt
with open('history_orunet_skin_lesion.json', 'r') as f:
    orunet = json.load(f)
print (len(orunet))
# Out:
# 6

# %%
import json
import matplotlib.pyplot as plt
with open('history_attn_1_bothsides_skinleison.json', 'r') as f:
    attn_1_proposed = json.load(f)
print (len(attn_1_proposed))
# Out:
# 6

# %%
"""
attnR2Unet
r2unet
attn_unet
multi_res_unet
UNet
orunet
"""

accuracy_attnR2Unet = []
for item in attnR2Unet['accuracy']:
    accuracy_attnR2Unet.append(attnR2Unet['accuracy'][item])

accuracy_r2unet = []
for item in r2unet['accuracy']:
    accuracy_r2unet.append(r2unet['accuracy'][item])

accuracy_attn_unet = []
for item in attn_unet['accuracy']:
    accuracy_attn_unet.append(attn_unet['accuracy'][item])

accuracy_multi_res_unet = []
for item in multi_res_unet['accuracy']:
    accuracy_multi_res_unet.append(multi_res_unet['accuracy'][item])

accuracy_UNet = []
for item in UNet['accuracy']:
    accuracy_UNet.append(UNet['accuracy'][item])
    
accuracy_orunet = []
for item in orunet['accuracy']:
    accuracy_orunet.append(orunet['accuracy'][item])
    
accuracy_attn_1_proposed = []
for item in attn_1_proposed['accuracy']:
    accuracy_attn_1_proposed.append(attn_1_proposed['accuracy'][item])

plt.figure(figsize=(10,6))
plt.title('Accuracy for Skin Lesion dataset')
#plt.plot(accuracy_attnR2Unet,color='green')
#plt.plot(accuracy_r2unet,color='blue')
#plt.plot(accuracy_attn_unet,color='orange')
plt.plot(accuracy_multi_res_unet,color='yellow')
plt.plot(accuracy_UNet,color='black')
plt.plot(accuracy_attn_1_proposed,color='red')
#plt.plot(accuracy_orunet,color='purple')

#plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet', 'Proposed Attn 1'],loc="lower right")
plt.legend(['MultiResUnet','Mod UNet', 'Proposed Attn 1'],loc="lower right")
plt.savefig('SKIN_LESION_accuracy_coef.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
"""
attnR2Unet
r2unet
attn_unet
multi_res_unet
UNet
orunet
"""
print("Accuracy for attnR2Unet = ",accuracy_attnR2Unet[-1])
print("Accuracy for r2unet = ",accuracy_r2unet[-1])
print("Accuracy for attn_unet = ",accuracy_attn_unet[-1])
print("Accuracy for multi_res_unet = ",accuracy_multi_res_unet[-1])
print("Accuracy for UNet = ",accuracy_UNet[-1])
print("Accuracy for orunet = ",accuracy_orunet[-1])
print("Accuracy for Proposed Attention 1 = ",accuracy_attn_1_proposed[-1])
# Out:
# Accuracy for attnR2Unet =  0.0568359382
# Accuracy for r2unet =  0.0089626741
# Accuracy for attn_unet =  0.0208441839
# Accuracy for multi_res_unet =  0.9795754552
# Accuracy for UNet =  0.9910959601
# Accuracy for orunet =  0.0489474833
# Accuracy for Proposed Attention 1 =  0.9751825929

# %%
"""
attnR2Unet
r2unet
attn_unet
multi_res_unet
UNet
orunet
"""

recall_attnR2Unet = []
for item in attnR2Unet['recall']:
    recall_attnR2Unet.append(attnR2Unet['recall'][item])

recall_r2unet = []
for item in r2unet['recall']:
    recall_r2unet.append(r2unet['recall'][item])

recall_attn_unet = []
for item in attn_unet['recall']:
    recall_attn_unet.append(attn_unet['recall'][item])

recall_multi_res_unet = []
for item in multi_res_unet['recall']:
    recall_multi_res_unet.append(multi_res_unet['recall'][item])

recall_UNet = []
for item in UNet['recall']:
    recall_UNet.append(UNet['recall'][item])
    
recall_orunet = []
for item in orunet['recall']:
    recall_orunet.append(orunet['recall'][item])

recall_attn_1_proposed = []
for item in attn_1_proposed['recall']:
    recall_attn_1_proposed.append(attn_1_proposed['recall'][item])
    
plt.figure(figsize=(10,6))
plt.title('Recall for Skin Lesion dataset')
plt.plot(recall_attnR2Unet,color='green')
plt.plot(recall_r2unet,color='blue')
plt.plot(recall_attn_unet,color='orange')
plt.plot(recall_multi_res_unet,color='yellow')
plt.plot(recall_UNet,color='black')
plt.plot(recall_orunet,color='purple')
plt.plot(recall_attn_1_proposed,color='red')

plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet','Proposed Attn 1'],loc="lower right")
plt.savefig('SKIN_LESION_recall.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
"""
attnR2Unet
r2unet
attn_unet
multi_res_unet
UNet
orunet
"""
print("Recall for attnR2Unet = ",recall_attnR2Unet[-1])
print("Recall for r2unet = ",recall_r2unet[-1])
print("Recall for attn_unet = ",recall_attn_unet[-1])
print("Recall for multi_res_unet = ",recall_multi_res_unet[-1])
print("Recall for UNet = ",recall_UNet[-1])
print("Recall for orunet = ",recall_orunet[-1])
print("Recall for Proposed Attention 1 = ",recall_attn_1_proposed[-1])
# Out:
# Recall for attnR2Unet =  0.9946857095
# Recall for r2unet =  0.9945585728
# Recall for attn_unet =  0.980804503
# Recall for multi_res_unet =  0.9754391909
# Recall for UNet =  0.9859021902
# Recall for orunet =  0.9792517424
# Recall for Proposed Attention 1 =  0.9569684863

# %%
"""
attnR2Unet
r2unet
attn_unet
multi_res_unet
UNet
orunet
"""

precision_attnR2Unet = []
for item in attnR2Unet['precision']:
    precision_attnR2Unet.append(attnR2Unet['precision'][item])

precision_r2unet = []
for item in r2unet['precision']:
    precision_r2unet.append(r2unet['precision'][item])

precision_attn_unet = []
for item in attn_unet['precision']:
    precision_attn_unet.append(attn_unet['precision'][item])

precision_multi_res_unet = []
for item in multi_res_unet['precision']:
    precision_multi_res_unet.append(multi_res_unet['precision'][item])

precision_UNet = []
for item in UNet['precision']:
    precision_UNet.append(UNet['precision'][item])
    
precision_orunet = []
for item in orunet['precision']:
    precision_orunet.append(orunet['precision'][item])

precision_attn_1_proposed = []
for item in attn_1_proposed['precision']:
    precision_attn_1_proposed.append(attn_1_proposed['precision'][item])
    
plt.figure(figsize=(10,6))
plt.title('Precision for Skin Lesion dataset')
plt.plot(precision_attnR2Unet,color='green')
plt.plot(precision_r2unet,color='blue')
plt.plot(precision_attn_unet,color='orange')
plt.plot(precision_multi_res_unet,color='yellow')
plt.plot(precision_UNet,color='black')
plt.plot(precision_orunet,color='purple')
plt.plot(precision_attn_1_proposed,color='red')


plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet','Proposed Attn 1'],loc="lower right")
plt.savefig('SKIN_LESION_precision.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
print("precision for attnR2Unet = ",precision_attnR2Unet[-1])
print("precision for r2unet = ",precision_r2unet[-1])
print("precision for attn_unet = ",precision_attn_unet[-1])
print("precision for multi_res_unet = ",precision_multi_res_unet[-1])
print("precision for UNet = ",precision_UNet[-1])
print("precision for orunet = ",precision_orunet[-1])
print("precision for Proposed Attention 1 = ",precision_attn_1_proposed[-1])
# Out:
# precision for attnR2Unet =  0.9946811199
# precision for r2unet =  0.9944600463
# precision for attn_unet =  0.9800108075
# precision for multi_res_unet =  0.9627292752
# precision for UNet =  0.9869146347
# precision for orunet =  0.9791479111
# precision for Proposed Attention 1 =  0.9669619799

# %%
"""
attnR2Unet
r2unet
attn_unet
multi_res_unet
UNet
orunet
"""

jacard_attnR2Unet = []
for item in attnR2Unet['jacard']:
    jacard_attnR2Unet.append(attnR2Unet['jacard'][item])

jacard_r2unet = []
for item in r2unet['jacard']:
    jacard_r2unet.append(r2unet['jacard'][item])

jacard_attn_unet = []
for item in attn_unet['jacard']:
    jacard_attn_unet.append(attn_unet['jacard'][item])

jacard_multi_res_unet = []
for item in multi_res_unet['jacard']:
    jacard_multi_res_unet.append(multi_res_unet['jacard'][item])

jacard_UNet = []
for item in UNet['jacard']:
    jacard_UNet.append(UNet['jacard'][item])
    
jacard_orunet = []
for item in orunet['jacard']:
    jacard_orunet.append(orunet['jacard'][item])

jacard_attn_1_proposed = []
for item in attn_1_proposed['jacard']:
    jacard_attn_1_proposed.append(attn_1_proposed['jacard'][item])
    
plt.figure(figsize=(10,6))
plt.title('jacard for Skin Lesion dataset')
plt.plot(jacard_attnR2Unet,color='green')
plt.plot(jacard_r2unet,color='blue')
plt.plot(jacard_attn_unet,color='orange')
plt.plot(jacard_multi_res_unet,color='yellow')
plt.plot(jacard_UNet,color='black')
plt.plot(jacard_orunet,color='purple')
plt.plot(jacard_attn_1_proposed,color='red')


plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet','Proposed Attn 1'],loc="lower right")
plt.savefig('SKIN_LESION_jacard.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
print("jacard for attnR2Unet = ",jacard_attnR2Unet[-1])
print("jacard for r2unet = ",jacard_r2unet[-1])
print("jacard for attn_unet = ",jacard_attn_unet[-1])
print("jacard for multi_res_unet = ",jacard_multi_res_unet[-1])
print("jacard for UNet = ",jacard_UNet[-1])
print("jacard for orunet = ",jacard_orunet[-1])
print("jacard for Proposed Attention 1 = ",jacard_attn_1_proposed[-1])
# Out:
# jacard for attnR2Unet =  0.9817077518
# jacard for r2unet =  0.9807921648
# jacard for attn_unet =  0.9340285063
# jacard for multi_res_unet =  0.4517361522
# jacard for UNet =  0.8781375885
# jacard for orunet =  0.9287748337
# jacard for Proposed Attention 1 =  0.6962176561

# %%
"""
attnR2Unet
r2unet
attn_unet
multi_res_unet
UNet
orunet
"""

loss_attnR2Unet = []
for item in attnR2Unet['loss']:
    loss_attnR2Unet.append(attnR2Unet['loss'][item])

loss_r2unet = []
for item in r2unet['loss']:
    loss_r2unet.append(r2unet['loss'][item])

loss_attn_unet = []
for item in attn_unet['loss']:
    loss_attn_unet.append(attn_unet['loss'][item])

loss_multi_res_unet = []
for item in multi_res_unet['loss']:
    loss_multi_res_unet.append(multi_res_unet['loss'][item])

loss_UNet = []
for item in UNet['loss']:
    loss_UNet.append(UNet['loss'][item])
    
loss_orunet = []
for item in orunet['loss']:
    loss_orunet.append(orunet['loss'][item])

loss_attn_1_proposed = []
for item in attn_1_proposed['loss']:
    loss_attn_1_proposed.append(attn_1_proposed['loss'][item])
    
plt.figure(figsize=(10,6))
plt.title('loss for Skin Lesion dataset')
plt.plot(loss_attnR2Unet,color='green')
plt.plot(loss_r2unet,color='blue')
plt.plot(loss_attn_unet,color='orange')
plt.plot(loss_multi_res_unet,color='yellow')
plt.plot(loss_UNet,color='black')
plt.plot(loss_orunet,color='purple')
plt.plot(loss_attn_1_proposed,color='red')


plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet','Proposed Attn 1'],loc="upper right")
plt.savefig('SKIN_LESION_loss.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
print("loss for attnR2Unet = ",loss_attnR2Unet[-1])
print("loss for r2unet = ",loss_r2unet[-1])
print("loss for attn_unet = ",loss_attn_unet[-1])
print("loss for multi_res_unet = ",loss_multi_res_unet[-1])
print("loss for UNet = ",loss_UNet[-1])
print("loss for orunet = ",loss_orunet[-1])
print("loss for Proposed Attention 1 = ",loss_attn_1_proposed[-1])
# Out:
# loss for attnR2Unet =  0.0081737172
# loss for r2unet =  0.0084621403
# loss for attn_unet =  0.0297463536
# loss for multi_res_unet =  0.3643286526
# loss for UNet =  0.04005583
# loss for orunet =  0.0318455733
# loss for Proposed Attention 1 =  0.1309675127

# %%
"""
attnR2Unet
r2unet
attn_unet
multi_res_unet
UNet
orunet
"""

dice_coef_attnR2Unet = []
for item in attnR2Unet['dice_coef']:
    dice_coef_attnR2Unet.append(attnR2Unet['dice_coef'][item])

dice_coef_r2unet = []
for item in r2unet['dice_coef']:
    dice_coef_r2unet.append(r2unet['dice_coef'][item])

dice_coef_attn_unet = []
for item in attn_unet['dice_coef']:
    dice_coef_attn_unet.append(attn_unet['dice_coef'][item])

dice_coef_multi_res_unet = []
for item in multi_res_unet['dice_coef']:
    dice_coef_multi_res_unet.append(multi_res_unet['dice_coef'][item])

dice_coef_UNet = []
for item in UNet['dice_coef']:
    dice_coef_UNet.append(UNet['dice_coef'][item])
    
dice_coef_orunet = []
for item in orunet['dice_coef']:
    dice_coef_orunet.append(orunet['dice_coef'][item])

dice_coef_attn_1_proposed = []
for item in attn_1_proposed['dice_coef']:
    dice_coef_attn_1_proposed.append(attn_1_proposed['dice_coef'][item])
    
plt.figure(figsize=(10,6))
plt.title('dice_coef for Skin Lesion dataset')
plt.plot(dice_coef_attnR2Unet,color='green')
plt.plot(dice_coef_r2unet,color='blue')
plt.plot(dice_coef_attn_unet,color='orange')
plt.plot(dice_coef_multi_res_unet,color='yellow')
plt.plot(dice_coef_UNet,color='black')
plt.plot(dice_coef_orunet,color='purple')
plt.plot(dice_coef_attn_1_proposed,color='red')


plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet','Proposed Attn 1'],loc="lower right")
plt.savefig('SKIN_LESION_dice_coef.eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
print("dice_coef for attnR2Unet = ",dice_coef_attnR2Unet[-1])
print("dice_coef for r2unet = ",dice_coef_r2unet[-1])
print("dice_coef for attn_unet = ",dice_coef_attn_unet[-1])
print("dice_coef for multi_res_unet = ",dice_coef_multi_res_unet[-1])
print("dice_coef for UNet = ",dice_coef_UNet[-1])
print("dice_coef for orunet = ",dice_coef_orunet[-1])
print("dice_coef for Proposed Attention 1 = ",dice_coef_attn_1_proposed[-1])
# Out:
# dice_coef for attnR2Unet =  0.9907550812
# dice_coef for r2unet =  0.9902863503
# dice_coef for attn_unet =  0.9656839371
# dice_coef for multi_res_unet =  0.6180320382
# dice_coef for UNet =  0.932923317
# dice_coef for orunet =  0.9628359675
# dice_coef for Proposed Attention 1 =  0.8146830797
