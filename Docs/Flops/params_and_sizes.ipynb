# %%
"""
# Of Params

AttnR2UNET  =  96,509,863
AttnUNet = 31,902,759
MultiResUNet = 7,238,228
OriginalUNet = 31,379,075
R2UNet = 95,986,179
Modified_UNet = 1,203,649
DRRMSAN = 8,205,389

"""
"""
# Sizes in MB

AttnR2UNET  = 369M  
AttnUNet = 122M
MultiResUNet = 29M  
OriginalUNet = 120M
R2UNet = 367M
Modified_UNet = 5.0M

"""
# Out:
# '\n# Sizes in MB\n\nAttnR2UNET  = 369M  \nAttnUNet = 122M\nMultiResUNet = 29M  \nOriginalUNet = 120M\nR2UNet = 367M\nModified_UNet = 5.0M\n\n'

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

y = [1.203649, 7.238228, 8.205389, 31.379075, 31.902759, 95.986179, 96.509863]
x = [1,2,3,4,5,6,7]
labels = ['Modified UNet','MultiResUNet', 'DRRMSAN', 'UNet','AttnUNet','R2UNet','AttnR2UNET']
width = 0.5
plt.title('No. of parameters in millions ',fontsize=20, fontname = 'Times New Roman', fontweight = 500)
plt.xticks(x, labels, rotation=75, fontsize=15, fontname = 'Times New Roman', fontweight = 500)
plt.bar(x, y, width, color='b')
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig('params.eps',bbox_inches='tight')
plt.show()

# %%
y_1 = [5.0, 29, 120, 122, 367, 369]
plt.title('Size in MB ')
plt.xticks(x, labels, rotation=75)
plt.bar(x, y_1, width, color='r')
plt.savefig('sizes.eps',bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-35c93c6470cf> in <module>
#       2 plt.title('Size in MB ')
#       3 plt.xticks(x, labels, rotation=75)
# ----> 4 plt.bar(x, y_1, width, color='r')
#       5 plt.savefig('sizes.eps',bbox_inches='tight')
#       6 plt.show()
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2485         x, height, width=0.8, bottom=None, *, align='center',
#    2486         data=None, **kwargs):
# -> 2487     return gca().bar(
#    2488         x, height, width=width, bottom=bottom, align=align,
#    2489         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
# ...
