# %%
"""
# Of Params

AttnR2UNET  =  96,509,863
AttnUNet = 31,902,759
MultiResUNet = 7,238,228
OriginalUNet = 31,379,075
R2UNet = 95,986,179
Modified_UNet = 1,203,649

"""
"""
# Sizes in MB

AttnR2UNET  = 369M  
AttnUNet = 122M
MultiResUNet = 29M  
OriginalUNet = 120M
R2UNet = 367M
Modified_UNet = 5.0M

"""

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

y = [1.203649, 7.238228, 31.379075, 31.902759, 95.986179, 96.509863]
x = [1,2,3,4,5,6]
labels = ['Modified UNet','MultiResUNet','UNet','AttnUNet','R2UNet','AttnR2UNET']
width = 0.5
plt.title('No. of parameters in millions ')
plt.xticks(x, labels, rotation=75)
plt.bar(x, y, width, color='b')
plt.savefig('params.eps',bbox_inches='tight')
plt.show()

# %%
y_1 = [5.0, 29, 120, 122, 367, 369]
plt.title('Size in MB ')
plt.xticks(x, labels, rotation=75)
plt.bar(x, y_1, width, color='r')
plt.savefig('sizes.eps',bbox_inches='tight')
plt.show()
